# %% [markdown]
# # LDA using Scikit Learn

# %%
import numpy as np
import pandas as pd
import re, nltk, spacy, gensim

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint

#Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Importing the data**

# %%
df = pd.read_csv("Company_Dataset/dataset_others.csv")
df = df.dropna(subset=["company_Link"])
df.head(3)
# Out:
#     Company                                           job_name  \
# 0  Spectrum                                Sr Technical Writer
# 1  Spectrum  Production Specialist I - Spectrum News 13 Orl...
# 2  Spectrum     Manager, Advanced Advertising Sales - Ad Sales
#
#                                             job_link ML Labeled Function  \
# 0  https://sjobs.brassring.com/TGnewUI/Search/hom...               Other
# 1  https://sjobs.brassring.com/TGnewUI/Search/hom...               Other
# 2  https://sjobs.brassring.com/TGnewUI/Search/hom...               Other
#
#           city        country   Function employment_type            remote  \
# 0    Englewood  United States  Full-time              No  Mid-Senior Level
# 1      Orlando  United States  Full-time              No  Mid-Senior Level
# 2  Los Angeles  United States  Full-time              No  Mid-Senior Level
#
#   seniority level  Job Status  Date Reviewed  data analyst  \
# 0  to be reviewed         NaN            NaN           NaN
# 1  to be reviewed         NaN            NaN           NaN
# 2  to be reviewed         NaN            NaN           NaN
#
#                                         company_Link  \
# 0  JOB SUMMARYThis position is responsible for de...
# 1  Spectrum Networks is looking for enthusiastic,...
# 2  Spectrum Reach is looking for a dynamic Manage...
#
#                            job_location  job_details  \
# 0  4175936f-1a2c-4635-a536-4348d5bf89f5          NaN
# 1  fc34ab5f-ee2d-4145-81c4-126f52b1df35          NaN
# 2  60391e39-17ba-4de2-a564-ede2412d6791          NaN
#
#                                               job_id  posting_error  \
# 0  https://www.smartrecruiters.com/Humanity/74399...            NaN
# 1  https://www.smartrecruiters.com/Humanity/74399...            NaN
# 2  https://www.smartrecruiters.com/Humanity/74399...            NaN
#
#    description  Clusters_Labelled
# 0          NaN                  7
# 1          NaN                  6
# 2          NaN                  0

# %% [markdown]
# **Data Cleaning**

# %%
# Convert to list
data = df['company_Link'].values.tolist()
print(data[0])
# Out:
# JOB SUMMARYThis position is responsible for developing and designing complex instructional and informational tools needed to assure safe, appropriate and effective use of engineering technology. Combines multi-media knowledge and strong communication skills with technical expertise to educate across the entire spectrum of users' abilities, technical experience, and visual and auditory capabilities.MAJOR DUTIES AND RESPONSIBILITIESWork closely with the subject matter experts, at all levels within the organization, to record and share technical documentation. Guides partners through discovery conversations to uncover the degree of detail and key information.Document operational procedures, engineering design documents, methods of procedures, implementation guides and engineering drawings.Manage the archiving, tracking and updating of reference materials across multiple media platforms. Responsible for QA, configuration management and version control of all documentationDesign, create material and conduct classes to train others on documentation techniques and practices.Edit information for accuracy and readability and reviews content in test scenarios to ensure materials are serving the intended purpose.Stay current on technical writing, editing and communication platform best practices and educates other technical writers.REQUIRED QUALIFICATIONSRequired Skills/Abilities and KnowledgeDemonstrated ability to articulate, translate and document methods and proceduresDemonstrated ability to utilize and quickly learn a wide range of technology tools related to documentationDemonstrated ability to utilize and quickly learn a wide range of changing telecommunication and MSO technologyDemonstrated ability to design and create multi format documentationRequired EducationBachelor's Degree in Communications, English, Instructional Design or other equivalent work experienceRequired Related Work Experience 5 - 7 years of technical writing work experienceWORKING CONDITIONSOffice environment

# %% [markdown]
# **Tokenize**

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['job', 'summarythis', 'position', 'is', 'responsible', 'for', 'developing', 'and', 'designing', 'complex', 'instructional', 'and', 'informational', 'tools', 'needed', 'to', 'assure', 'safe', 'appropriate', 'and', 'effective', 'use', 'of', 'engineering', 'technology', 'combines', 'multi', 'media', 'knowledge', 'and', 'strong', 'communication', 'skills', 'with', 'technical', 'expertise', 'to', 'educate', 'across', 'the', 'entire', 'spectrum', 'of', 'users', 'abilities', 'technical', 'experience', 'and', 'visual', 'and', 'auditory', 'capabilities', 'major', 'duties', 'and', 'closely', 'with', 'the', 'subject', 'matter', 'experts', 'at', 'all', 'levels', 'within', 'the', 'organization', 'to', 'record', 'and', 'share', 'technical', 'documentation', 'guides', 'partners', 'through', 'discovery', 'conversations', 'to', 'uncover', 'the', 'degree', 'of', 'detail', 'and', 'key', 'information', 'document', 'operational', 'procedures', 'engineering', 'design', 'documents', 'methods', 'of', 'procedures', 'implementation', 'guides', 'and', 'engineering', 'drawings', 'manage', 'the', 'archiving', 'tracking', 'and', 'updating', 'of', 'reference', 'materials', 'across', 'multiple', 'media', 'platforms', 'responsible', 'for', 'qa', 'configuration', 'management', 'and', 'version', 'control', 'of', 'all', 'create', 'material', 'and', 'conduct', 'classes', 'to', 'train', 'others', 'on', 'documentation', 'techniques', 'and', 'practices', 'edit', 'information', 'for', 'accuracy', 'and', 'readability', 'and', 'reviews', 'content', 'in', 'test', 'scenarios', 'to', 'ensure', 'materials', 'are', 'serving', 'the', 'intended', 'purpose', 'stay', 'current', 'on', 'technical', 'writing', 'editing', 'and', 'communication', 'platform', 'best', 'practices', 'and', 'educates', 'other', 'technical', 'writers', 'required', 'skills', 'abilities', 'and', 'ability', 'to', 'articulate', 'translate', 'and', 'document', 'methods', 'and', 'ability', 'to', 'utilize', 'and', 'quickly', 'learn', 'wide', 'range', 'of', 'technology', 'tools', 'related', 'to', 'ability', 'to', 'utilize', 'and', 'quickly', 'learn', 'wide', 'range', 'of', 'changing', 'and', 'mso', 'ability', 'to', 'design', 'and', 'create', 'multi', 'format', 'degree', 'in', 'communications', 'english', 'instructional', 'design', 'or', 'other', 'equivalent', 'work', 'related', 'work', 'experience', 'years', 'of', 'technical', 'writing', 'work', 'environment']]

# %% [markdown]
# **Stemming**

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# Initialize spacy ‘en’ model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_lemmatized = lemmatization(data_words, allowed_postags=["NOUN", "VERB"]) #select noun and verb
print(data_lemmatized[:2])
# Out:
# ['job position be develop design tool need assure use engineering technology combine medium knowledge communication skill expertise educate spectrum user abilitie experience auditory capability duty matter expert level organization record share documentation guide partner discovery conversation uncover degree detail information document procedure engineering design document method procedure implementation guide engineering drawing manage archive tracking updating reference material medium platform configuration management version control create material conduct class train other documentation technique practice edit information accuracy readability review content test scenario ensure material be serve intend purpose stay writing editing communication platform practice educate writer require skill ability ability articulate translate document method ability utilize learn range technology tool relate ability utilize learn range change ability design create format degree communication design work relate work experience year writing work environment', 'spectrum network be look drive individual join gather produce deliver story make difference hour break news environment commitment be engage viewer news community serve be spectrum network be series news sport network own operate spectrum network seek provide news information cultivate conversation foster inform engage community environment spectrum news be hour break news network require employee be work shift include morning evening weekend holiday be team mean inspire be inspire passionate drive flourish pace environment re desire leverage knowledge skill ability share news story viewer community re have ability pivot change workflow be team player attitude skill have ability multi task meet deadline remain pressure look production specialist be run studio camera include camera time operate broadcast equipment edit lighting master control use pre record programming duty support effort simplify enhance customer experience communicate spectrum network personnel operate jib studio camera production setting operate mix console set maintain studio equipment operate studio light light program play staff control room staff coordinate medium resource spectrum network be cover master control duty absence master control operator be monitor close captioning news channel accuracy order live participate training program initiative develop skill contribute team operate teleprompter event create display graphic use chyron system work playback operator provide support director pre tape production originate broadcast facility tune satellite shot ingest medium use control software video server']

# %% [markdown]
# **Vectorizing**

# %%
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=10,
# minimum reqd occurences of a word 
                             stop_words='english',             
# remove stop words
                             lowercase=True,                   
# convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  
# num chars > 3
                             # max_features=50000,             
# max number of uniq words    
                            ngram_range=(1, 3))
data_vectorized = vectorizer.fit_transform(data_lemmatized)
data_vectorized
# Out:
# <687x8981 sparse matrix of type '<class 'numpy.int64'>'
# 	with 315407 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **LDA Model using sklearn**

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=20,               # Number of topics
                                      max_iter=10,               
# Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          
# Random state
                                      batch_size=128,            
# n docs in each learning iter
                                      evaluate_every = -1,       
# compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               
# Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)  # Model attributes
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=20, n_jobs=-1,
#                           random_state=100)

# %%
LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
 evaluate_every=-1, learning_decay=0.7,
 learning_method="online", learning_offset=10.0,
 max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
 n_components=10, n_jobs=-1, perp_tol=0.1,
 random_state=100, topic_word_prior=None,
 total_samples=1000000.0, verbose=0)
# Out:
# LatentDirichletAllocation(learning_method='online', n_jobs=-1, random_state=100)

# %% [markdown]
# **Diagnosing model performance with perplexity and log-likelihood**

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))
# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -2852044.439039415
# Perplexity:  1188.597938401916
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 20,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %% [markdown]
# **Finding out Optimum number of topics using GridSearch**

# %%
# Define Search Param
search_params = {'n_components': [5, 10, 15, 20, 25], 'learning_decay': [.5, .7, .9]}

# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)

# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
model.fit(data_vectorized)
GridSearchCV(cv=None, error_score='raise',
       estimator=LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7, learning_method=None,
             learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
             mean_change_tol=0.001, n_components=10, n_jobs=1, perp_tol=0.1, random_state=None,
             topic_word_prior=None, total_samples=1000000.0, verbose=0), n_jobs=1,
       param_grid={'n_topics': [5, 10, 15, 20, 25], 'learning_decay': [0.5, 0.7, 0.9]},
       pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
       scoring=None, verbose=0)
# Out:
# GridSearchCV(error_score='raise',
#              estimator=LatentDirichletAllocation(learning_method=None,
#                                                  n_jobs=1),
#              n_jobs=1,
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_topics': [5, 10, 15, 20, 25]},
#              return_train_score='warn')

# %%
# Best Model
best_lda_model = model.best_estimator_
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 10}
# Best Log Likelihood Score:  -669859.1337022403
# Model Perplexity:  1445.6643499819388

# %% [markdown]
# Grid Search has concluded that a maximum of 10 topics is optimal.

# %% [markdown]
# **Dominant topic in each job posting**

# %%
# Create Document — Topic Matrix
lda_output = best_lda_model.transform(data_vectorized)
# column names
topicnames = ["Cluster " + str(i) for i in range(best_lda_model.n_components)]
# index names
docnames = ["Job " + str(i) for i in range(len(data))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic["dominant_topic"] = dominant_topic
# Styling
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return "color: {col}".format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return "font-weight: {weight}".format(weight=weight)
# Apply Style
df_document_topics = df_document_topic.style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_19fe8_row0_col0, #T_19fe8_row0_col1, #T_19fe8_row0_col2, #T_19fe8_row0_col3, #T_19fe8_row0_col4, #T_19fe8_row0_col5, #T_19fe8_row0_col8, #T_19fe8_row0_col9, #T_19fe8_row1_col0, #T_19fe8_row1_col1, #T_19fe8_row1_col2, #T_19fe8_row1_col3, #T_19fe8_row1_col4, #T_19fe8_row1_col5, #T_19fe8_row1_col7, #T_19fe8_row1_col8, #T_19fe8_row1_col9, #T_19fe8_row2_col0, #T_19fe8_row2_col1, #T_19fe8_row2_col2, #T_19fe8_row2_col4, #T_19fe8_row2_col5, #T_19fe8_row2_col6, #T_19fe8_row2_col8, #T_19fe8_row3_col0, #T_19fe8_row3_col1, #T_19fe8_row3_col2, #T_19fe8_row3_col3, #T_19fe8_row3_col4, #T_19fe8_row3_col5, #T_19fe8_row3_col6, #T_19fe8_row3_col8, #T_19fe8_row3_col9, #T_19fe8_row4_col0, #T_19fe8_row4_col1, #T_19fe8_row4_col2, #T_19fe8_row4_col3, #T_19fe8_row4_col4, #T_19fe8_row4_col5, #T_19fe8_row4_col6, #T_19fe8_row4_col8, #T_19fe8_row4_col9, #T_19fe8_row5_col0, #T_19fe8_row5_col1, #T_19fe8_row5_col3, #T_19fe8_row5_col4, #T_19fe8_row5_col5, #T_19fe8_row5_col6, #T_19fe8_row5_col8, #T_19fe8_row5_col9, #T_19fe8_row6_col0, #T_19fe8_row6_col1, #T_19fe8_row6_col3, #T_19fe8_row6_col4, #T_19fe8_row6_col5, #T_19fe8_row6_col6, #T_19fe8_row6_col7, #T_19fe8_row6_col8, #T_19fe8_row6_col9, #T_19fe8_row7_col0, #T_19fe8_row7_col1, #T_19fe8_row7_col2, #T_19fe8_row7_col3, #T_19fe8_row7_col4, #T_19fe8_row7_col5, #T_19fe8_row7_col6, #T_19fe8_row7_col8, #T_19fe8_row7_col9, #T_19fe8_row8_col0, #T_19fe8_row8_col1, #T_19fe8_row8_col2, #T_19fe8_row8_col4, #T_19fe8_row8_col5, #T_19fe8_row8_col6, #T_19fe8_row8_col7, #T_19fe8_row8_col9, #T_19fe8_row9_col0, #T_19fe8_row9_col1, #T_19fe8_row9_col3, #T_19fe8_row9_col4, #T_19fe8_row9_col5, #T_19fe8_row9_col6, #T_19fe8_row9_col8, #T_19fe8_row9_col9, #T_19fe8_row10_col0, #T_19fe8_row10_col1, #T_19fe8_row10_col2, #T_19fe8_row10_col3, #T_19fe8_row10_col4, #T_19fe8_row10_col5, #T_19fe8_row10_col6, #T_19fe8_row10_col8, #T_19fe8_row10_col9, #T_19fe8_row11_col0, #T_19fe8_row11_col1, #T_19fe8_row11_col3, #T_19fe8_row11_col4, #T_19fe8_row11_col5, #T_19fe8_row11_col6, #T_19fe8_row11_col8, #T_19fe8_row11_col9, #T_19fe8_row12_col0, #T_19fe8_row12_col1, #T_19fe8_row12_col2, #T_19fe8_row12_col3, #T_19fe8_row12_col4, #T_19fe8_row12_col5, #T_19fe8_row12_col6, #T_19fe8_row12_col8, #T_19fe8_row13_col0, #T_19fe8_row13_col1, #T_19fe8_row13_col2, #T_19fe8_row13_col3, #T_19fe8_row13_col4, #T_19fe8_row13_col5, #T_19fe8_row13_col6, #T_19fe8_row13_col8, #T_19fe8_row13_col9, #T_19fe8_row14_col0, #T_19fe8_row14_col1, #T_19fe8_row14_col2, #T_19fe8_row14_col3, #T_19fe8_row14_col4, #T_19fe8_row14_col5, #T_19fe8_row14_col6, #T_19fe8_row14_col7, #T_19fe8_row14_col8, #T_19fe8_row15_col0, #T_19fe8_row15_col1, #T_19fe8_row15_col2, #T_19fe8_row15_col3, #T_19fe8_row15_col4, #T_19fe8_row15_col5, #T_19fe8_row15_col6, #T_19fe8_row15_col8, #T_19fe8_row15_col9, #T_19fe8_row16_col0, #T_19fe8_row16_col1, #T_19fe8_row16_col3, #T_19fe8_row16_col4, #T_19fe8_row16_col5, #T_19fe8_row16_col6, #T_19fe8_row16_col8, #T_19fe8_row16_col9, #T_19fe8_row17_col0, #T_19fe8_row17_col1, #T_19fe8_row17_col2, #T_19fe8_row17_col3, #T_19fe8_row17_col4, #T_19fe8_row17_col5, #T_19fe8_row17_col6, #T_19fe8_row17_col8, #T_19fe8_row17_col9, #T_19fe8_row18_col0, #T_19fe8_row18_col1, #T_19fe8_row18_col3, #T_19fe8_row18_col4, #T_19fe8_row18_col5, #T_19fe8_row18_col6, #T_19fe8_row18_col8, #T_19fe8_row18_col9, #T_19fe8_row19_col0, #T_19fe8_row19_col1, #T_19fe8_row19_col2, #T_19fe8_row19_col3, #T_19fe8_row19_col4, #T_19fe8_row19_col5, #T_19fe8_row19_col6, #T_19fe8_row19_col8, #T_19fe8_row20_col0, #T_19fe8_row20_col2, #T_19fe8_row20_col3, #T_19fe8_row20_col4, #T_19fe8_row20_col5, #T_19fe8_row20_col6, #T_19fe8_row20_col7, #T_19fe8_row20_col8, #T_19fe8_row21_col0, #T_19fe8_row21_col1, #T_19fe8_row21_col2, #T_19fe8_row21_col3, #T_19fe8_row21_col4, #T_19fe8_row21_col5, #T_19fe8_row21_col6, #T_19fe8_row21_col7, #T_19fe8_row21_col8, #T_19fe8_row22_col0, #T_19fe8_row22_col1, #T_19fe8_row22_col2, #T_19fe8_row22_col3, #T_19fe8_row22_col5, #T_19fe8_row22_col6, #T_19fe8_row22_col7, #T_19fe8_row22_col8, #T_19fe8_r ...

# %% [markdown]
# Relevant topics are in green

# %% [markdown]
# **Checking the clusters**

# %% [markdown]
# Top 20 keywords of each cluster:

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=best_lda_model, n_words=20)
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Cluster '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#                 Word 0    Word 1          Word 2      Word 3    Word 4  \
# Cluster 0        learn      test       education        team    ensure
# Cluster 1          aos     datum        consumer        work   payroll
# Cluster 2    equipment      work         company     network   perform
# Cluster 3  advertising     reach  spectrum reach     account  campaign
# Cluster 4   internship   include     opportunity  experience  business
# Cluster 5     washburn   student      employment    employee       job
# Cluster 6         news      team         network     ability  spectrum
# Cluster 7         work  customer         ability  experience   service
# Cluster 8     customer      team            sale       store      work
# Cluster 9       client      team            sale       datum      work
#
#                Word 5           Word 6       Word 7       Word 8    Word 9  \
# Cluster 0   integrity          payroll   experience         make      work
# Cluster 1        team           client     solution  information    status
# Cluster 2         use          ability       repair      require      test
# Cluster 3        sale         spectrum       client         team    medium
# Cluster 4       field             team       people     spectrum  industry
# Cluster 5      auburn  auburn washburn      provide      include       law
# Cluster 6        work            story  environment        skill   include
# Cluster 7     support             team          job      company     field
# Cluster 8  experience       management     spectrum     employee   manager
# Cluster 9         aos         business   experience     solution   company
#
#                     Word 10      Word 11           Word 12        Word 13  \
# Cluster 0          customer  application           testing           join
# Cluster 1         nielseniq       action              good     aos happen
# Cluster 2             plant       record           include           tool
# Cluster 3          position      support  advertising sale       research
# Cluster 4       development      program            intern        nielsen
# Cluster 5        origin age         race        race color         origin
# Cluster 6  spectrum network    community             drive  skill ability
# Cluster 7        management      include         knowledge        product
# Cluster 8           ability      provide             build          skill
# Cluster 9           provide       status            manage    information
#
#               Word 14      Word 15        Word 16              Word 17  \
# Cluster 0         job          aos       turnitin              service
# Cluster 1      happen      provide          world                  tax
# Cluster 2      ladder  maintenance          fiber                power
# Cluster 3    solution       market      marketing             customer
# Cluster 4         aos       design           time                 aoll
# Cluster 5         age     religion          color  race color religion
# Cluster 6     content        break          write                 look
# Cluster 7    business      require  communication               ensure
# Cluster 8        meet      product        service          environment
# Cluster 9  management     consumer        develop              service
#
#                   Word 18     Word 19
# Cluster 0     institution        year
# Cluster 1         insight  experience
# Cluster 2         operate    standard
# Cluster 3          screen     ability
# Cluster 4         project        work
# Cluster 5  color religion  disability
# Cluster 6         produce  break news
# Cluster 7           skill     provide
# Cluster 8         culture        care
# Cluster 9     opportunity       drive

# %%
#Topics = ["Update Version/Fix Crash Problem","Download/Internet Access","Learn and Share","Card Payment","Notification/Support", 
          #"Account Problem", "Device/Design/Password", "Language/Recommend/Screen Size", "Graphic/ Game Design/ Level and Coin", "Photo/Search"]
df_topic_keywords["Job Type"]= ""
df_topic_keywords
# Out:
#                 Word 0    Word 1          Word 2      Word 3    Word 4  \
# Cluster 0        learn      test       education        team    ensure
# Cluster 1          aos     datum        consumer        work   payroll
# Cluster 2    equipment      work         company     network   perform
# Cluster 3  advertising     reach  spectrum reach     account  campaign
# Cluster 4   internship   include     opportunity  experience  business
# Cluster 5     washburn   student      employment    employee       job
# Cluster 6         news      team         network     ability  spectrum
# Cluster 7         work  customer         ability  experience   service
# Cluster 8     customer      team            sale       store      work
# Cluster 9       client      team            sale       datum      work
#
#                Word 5           Word 6       Word 7       Word 8    Word 9  \
# Cluster 0   integrity          payroll   experience         make      work
# Cluster 1        team           client     solution  information    status
# Cluster 2         use          ability       repair      require      test
# Cluster 3        sale         spectrum       client         team    medium
# Cluster 4       field             team       people     spectrum  industry
# Cluster 5      auburn  auburn washburn      provide      include       law
# Cluster 6        work            story  environment        skill   include
# Cluster 7     support             team          job      company     field
# Cluster 8  experience       management     spectrum     employee   manager
# Cluster 9         aos         business   experience     solution   company
#
#            ...      Word 11           Word 12        Word 13     Word 14  \
# Cluster 0  ...  application           testing           join         job
# Cluster 1  ...       action              good     aos happen      happen
# Cluster 2  ...       record           include           tool      ladder
# Cluster 3  ...      support  advertising sale       research    solution
# Cluster 4  ...      program            intern        nielsen         aos
# Cluster 5  ...         race        race color         origin         age
# Cluster 6  ...    community             drive  skill ability     content
# Cluster 7  ...      include         knowledge        product    business
# Cluster 8  ...      provide             build          skill        meet
# Cluster 9  ...       status            manage    information  management
#
#                Word 15        Word 16              Word 17         Word 18  \
# Cluster 0          aos       turnitin              service     institution
# Cluster 1      provide          world                  tax         insight
# Cluster 2  maintenance          fiber                power         operate
# Cluster 3       market      marketing             customer          screen
# Cluster 4       design           time                 aoll         project
# Cluster 5     religion          color  race color religion  color religion
# Cluster 6        break          write                 look         produce
# Cluster 7      require  communication               ensure           skill
# Cluster 8      product        service          environment         culture
# Cluster 9     consumer        develop              service     opportunity
#
#               Word 19 Job Type
# Cluster 0        year
# Cluster 1  experience
# Cluster 2    standard
# Cluster 3     ability
# Cluster 4        work
# Cluster 5  disability
# Cluster 6  break news
# Cluster 7     provide
# Cluster 8        care
# Cluster 9       drive
#
# [10 rows x 21 columns]

# %%
df_document_topics.to_excel("LDA_Scikit_Cluster_Labeled.xlsx")

# %% [markdown]
# **Source:** https://yanlinc.medium.com/how-to-build-a-lda-topic-model-using-from-text-601cdcbfd3a6
